# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## word2vec 임포트

# %%
from gensim.models import Word2Vec
ko_model= Word2Vec.load('word2vec_movie.model')

# %%
# 모델 확인 
ko_model['평점']
# Out:
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([ 1.37894905e+00,  9.87708807e-01, -5.03856897e-01, -5.77842712e-01,
#         2.71781266e-01, -4.84355837e-01,  7.09133685e-01,  4.83562052e-01,
#        -2.12013578e+00, -1.53143942e+00, -2.21780896e+00, -4.36312646e-01,
#        -7.34049320e-01,  1.32041967e+00, -5.64270079e-01, -1.27724886e+00,
#        -6.67323589e-01,  1.25785872e-01,  8.86485755e-01,  5.52864611e-01,
#         1.83218852e-01,  3.81816566e-01, -1.45142281e+00,  1.32863295e+00,
#        -2.28901446e-01, -8.47232699e-01, -1.07557023e+00,  1.31017220e+00,
#        -1.11492407e+00,  4.67573434e-01, -1.73956227e+00,  5.30944943e-01,
#        -7.81446993e-01,  8.03073198e-02,  1.06718056e-02, -7.76855171e-01,
#        -5.18462360e-01,  1.82522148e-01, -3.42364371e-01,  8.30587745e-01,
#        -6.77727163e-01,  2.17546612e-01, -8.99270713e-01,  3.50216419e-01,
#         1.27970874e-01, -1.43166259e-02, -6.87184393e-01,  7.87147760e-01,
#         3.13703835e-01, -1.34181023e+00, -2.88948655e-01,  4.87908751e-01,
#        -4.40034330e-01, -1.24677551e+00,  1.91388345e+00,  6.20720275e-02,
#         2.17562735e-01,  1.57734001e+00, -9.75034893e-01, -9.16822493e-01,
#        -1.28605997e-03, -9.09354508e-01,  6.59039021e-02, -1.49107993e-01,
#         7.56315291e-01, -2.35793933e-01, -4.70089018e-02, -1.36861193e+00,
#        -1.82109869e+00, -2.76795030e-01, -1.14091682e+00,  5.86995006e-01,
#        -1.56029269e-01, -7.26923466e-01,  1.91490936e+00,  1.51382649e+00,
#         1.50504267e+00,  8.43366921e-01, -5.34677446e-01, -1.56727165e-01,
#        -1.01984635e-01,  2.61996478e-01,  6.94197237e-01, -1.58868562e-02,
#        -2.45960546e+00,  7.53313005e-01, -2.39308095e+00, -1.71987832e-01,
#        -7.16078401e-01, -2.36521065e-02,  1.96674049e-01,  2.53489375e-01,
#        -1.37074280e+00,  1.99862218e+00, -1.62576354e+00, -9.51833278e-02,
#        -2.33517003e+00, -1.19210348e-01, -5.35374522e-01,  5.34276724e-01,
#         3.40814203e-01, -9.24165905e-01,  4.04475778e-01,  1.42486405e+00,
#         6.24129474e-01,  1.50174610e-02, -5.80463648e-01, -1.29222524e+00,
#         4.28030491e-02,  7.02565312e-01,  8.17283809e-01,  8.40790153e-01,
#        -3.29402745e-01, -1.98169827e+00, -1.63232219e+00, -1.35585296e+00,
#         1.65320903e-01,  8.78293335e-01, -5.97452402e-01, -1.20649469e+00,
#         1.48789003e-01, -2.45120630e-01, -4.30667073e-01,  7.01792955e-01,
#        -6.28360271e-01, -1.01060845e-01,  9.60004985e-01,  1.21269250e+00,
#        -6.82425559e-01,  4.79231983e-01, -1.70215476e+00,  1.10598314e+00,
#         2.02842426e+00, -6.66181982e-01,  1.52281523e-01,  1.93755940e-01,
#         8.20553601e-01,  3.45031060e-02, -6.68196499e-01,  1.61060047e+00,
#         2.65534937e-01,  1.24002767e+00,  1.61996996e+00, -2.00592852e+00,
#         6.29359245e-01, -1.35131919e+00,  2.76473194e-01, -4.46986228e-01,
#        -2.53276855e-01,  1.53764343e+00,  6.05187058e-01,  6.05335459e-02,
#        -5.39341196e-02,  5.79544425e-01,  4.22562987e-01, -1.97442901e+00,
#         9.51142833e-02, -9.14012849e-01, -5.47553599e-01, -5.43647826e-01,
#         3.91458243e-01, -1.23735213e+00, -1.14660323e+00,  1.74715757e+00,
#         6.80540562e-01,  2.29177308e+00,  6.59082353e-01,  1.84193575e+00,
#        -1.89989954e-01, -9.19043645e-02,  1.62832558e+00,  8.45791772e-02,
#        -1.06711626e-01, -1.12618256e+00, -1.31909204e+00,  2.38393173e-01,
#        -5.44293463e-01,  2.38525525e-01, -2.90395641e+00, -5.06984890e-01,
#        -6.50369704e-01, -1.33505285e+00,  6.70029342e-01, -3.81612420e-01,
#        -2.00835848e+00,  1.00355136e+00, -6.54984117e-01,  1.10105038e+00,
#         1.05699301e-01,  6.22650683e-01,  4.73337799e-01, -2.59310812e-01,
#         4.99202013e-01,  7.38488376e-01, -1.88814163e+00,  7.97092259e-01,
#         1.51610231e+00,  2.06020311e-01, -1.39211369e+00, -2.56290108e-01],
#       dtype=float32)

# %%
print(ko_model.wv.most_similar("최민식"))
# Out:
# [('한석규', 0.9022693634033203), ('이민호', 0.8778703808784485), ('이미숙', 0.8716947436332703), ('설경구', 0.8695714473724365), ('김명민', 0.8679181933403015), ('이정재', 0.863978385925293), ('정재영', 0.8619986176490784), ('메릴', 0.8613458871841431), ('이주승', 0.861168622970581), ('공리', 0.8594560027122498)]

# %% [markdown]
# ## Train Test Data 불러오기

# %%
import pickle
import pandas as pd
test = pd.read_pickle("token_test_data.pkl")
train = pd.read_pickle("token_train_data.pkl")

# train, test 명시 
training_sentences = train['tokens']
testing_sentences = test['tokens']

training_labels = train['labels']
testing_labels = test['labels']

training_sentences.shape, testing_sentences.shape, training_labels.shape, testing_labels.shape
# Out:
# ((145791,), (48995,), (145791,), (48995,))

# %%
training_sentences
# Out:
# 0                                  [더빙, 진짜, 짜증나다, 목소리]
# 1                 [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 가볍다]
# 2                                 [무재, 밓었, 다그, 래서, 추천]
# 3                 [교도소, 이야기, 구먼, 솔직하다, 재미, 없다, 평점, 조정]
# 4         [몬페, 의, 익살스럽다, 연기, 영화, 스파이더맨, 커스틴, 던스트, 이쁘다]
#                               ...
# 145786                                 [인간, 문제, 소, 죄인]
# 145787                                        [평점, 낮다]
# 145788                  [이, 뭐, 한국인, 먹거리, 필리핀, 혼혈, 착하다]
# 145789                 [청춘, 영화, 최고봉, 방황, 우울하다, 날, 자화상]
# 145790                        [한국, 영화, 최초, 수간, 내용, 영화]
# Name: tokens, Length: 145791, dtype: object

# %% [markdown]
# ## Tokenize / Padding

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 파라미터 명시 
vocab_size = 20000
embedding_dim = 200
max_length = 30
truct_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

word_index, len(word_index)
# Out:
# ({'<OOV>': 1,
#   '영화': 2,
#   '없다': 3,
#   '있다': 4,
#   '좋다': 5,
#   '재밌다': 6,
#   '정말': 7,
#   '것': 8,
#   '같다': 9,
#   '진짜': 10,
#   '아니다': 11,
#   '점': 12,
#   '이': 13,
#   '연기': 14,
#   '평점': 15,
#   '최고': 16,
#   '왜': 17,
#   '스토리': 18,
#   '생각': 19,
#   '드라마': 20,
#   '감동': 21,
#   '사람': 22,
#   '보고': 23,
#   '말': 24,
#   '이렇다': 25,
#   '아깝다': 26,
#   '더': 27,
#   '배우': 28,
#   '때': 29,
#   '감독': 30,
#   '거': 31,
#   '내': 32,
#   '재미있다': 33,
#   '뭐': 34,
#   '시간': 35,
#   '재미': 36,
#   '내용': 37,
#   '그냥': 38,
#   '좀': 39,
#   '그': 40,
#   '지루하다': 41,
#   '재미없다': 42,
#   '쓰레기': 43,
#   '수': 44,
#   '그렇다': 45,
#   '작품': 46,
#   '사랑': 47,
#   '나': 48,
#   '하나': 49,
#   '다시': 50,
#   '마지막': 51,
#   '볼': 52,
#   '이다': 53,
#   '정도': 54,
#   '처음': 55,
#   '완전': 56,
#   '많다': 57,
#   '장면': 58,
#   '액션': 59,
#   '주인공': 60,
#   '안되다': 61,
#   '돈': 62,
#   '최악': 63,
#   '이야기': 64,
#   '지금': 65,
#   '걸': 66,
#   '느낌': 67,
#   '연출': 68,
#   '임': 69,
#   '끝': 70,
#   '듯': 71,
#   '좋아하다': 72,
#   '명작': 73,
#   '별로': 74,
#   '년': 75,
#   '역시': 76,
#   '개': 77,
#   '이해': 78,
#   '안': 79,
#   '이영화': 80,
#   '괜찮다': 81,
#   '또': 82,
#   '때문': 83,
#   '여자': 84,
#   '아름답다': 85,
#   '꼭': 86,
#   '보기': 87,
#   '기억': 88,
#   '결말': 89,
#   '편': 90,
#   '난': 91,
#   '분': 92,
#   '어떻다': 93,
#   '중': 94,
#   '아쉽다': 95,
#   '인생': 96,
#   '마음': 97,
#   '소재': 98,
#   '뻔하다': 99,
#   '못': 100,
#   '애': 101,
#   '수준': 102,
#   '무섭다': 103,
#   '현실': 104,
#   '한번': 105,
#   '가장': 106,
#   '반전': 107,
#   '매력': 108,
#   '전개': 109,
#   '남자': 110,
#   '한국': 111,
#   '가슴': 112,
#   '낮다': 113,
#   '아이': 114,
#   '슬프다': 115,
#   '높다': 116,
#   '유치하다': 117,
#   '음악': 118,
#   '알': 119,
#   '멋지다': 120,
#   '원작': 121,
#   '저': 122,
#   '줄': 123,
#   '게': 124,
#   '인간': 125,
#   '솔직하다': 126,
#   '우리': 127,
#   '추천': 128,
#   '눈물': 129,
#   '무슨': 130,
#   '만': 131,
#   '속': 132,
#   '함': 133,
#   '자체': 134,
#   '번': 135,
#   '야하다': 136,
#   '눈': 137,
#   '짜증나다': 138,
#   '코미디': 139,
#   '캐릭터': 140,
#   '대한': 141,
#   '움': 142,
#   '뭔가': 143,
#   '이상': 144,
#   '대박': 145,
#   '전혀': 146,
#   '이쁘다': 147,
#   '도': 148,
#   '연기력': 149,
#   '여운': 150,
#   '미치다': 151,
#   '모두': 152,
#   '개봉': 153,
#   '공감': 154,
#   '일본': 155,
#   '기대': 156,
#   '기대하다': 157,
#   '시리즈': 158,
#   '중간': 159,
#   '영상': 160,
#   '부분': 161,
#   '아주': 162,
#   '모습': 163,
#   '귀엽다': 164,
#   '제목': 165,
#   '계속': 166,
#   '가족': 167,
#   '내내': 168,
#   '전': 169,
#   '보지': 170,
#   '뿐': 171,
#   '진심': 172,
#   '다른': 173,
#   '무엇': 174,
#   '몰입': 175,
#   '실망': 176,
#   '표현': 177,
#   '후': 178,
#   '급': 179,
#   '기분': 180,
#   '대단하다': 181,
#   '별': 182,
#   '작가': 183,
#   '잔잔하다': 184,
#   '요': 185,
#   '이제': 186,
#   '위': 187,
#   '요즘': 188,
#   '공포': 189,
#   '스릴러': 190,
#   '감': 191,
#   '긴장감': 192,
#   '개인': 193,
#   '용': 194,
#   '모든': 195,
#   '잼': 196,
#   '조금': 197,
#   '애니': 198,
#   '대사': 199,
#   '알바': 200,
#   '이유': 201,
#   '제대로': 202,
#   '삶': 203,
#   '극장': 204,
#   '건': 205,
#   '점도': 206,
#   '노래': 207,
#   '욕': 208,
#   '굿': 209,
#   '점수': 210,
#   '시작': 211,
#   '막장': 212,
#   '나름': 213,
#   '예쁘다': 214,
#   '이상하다': 215,
#   '깊다': 216,
#   '제일': 217,
#   '차라리': 218,
#   '놈': 219,
#   '친구': 220,
#   '영화로': 221,
#   '당시': 222,
#   '노잼': 223,
#   '어설프다': 224,
#   '의미': 225,
#   '절대': 226,
#   '일': 227,
#   '기': 228,
#   '위해': 229,
#   '류': 230,
#   '세상': 231,
#   '따뜻하다': 232,
#   '미국': 233,
#   '훌륭하다': 234,
#   '공포영화': 235,
#   '년대': 236,
#   '도대체': 237,
#   '웃음': 238,
#   '제': 239,
#   '설정': 240,
#   '앞': 241,
#   '짱': 242,
#   '힘들다': 243,
#   '초반': 244,
#   '다르다': 245,
#   '물': 246,
#   '뭘': 247,
#   '우리나라': 248,
#   '출연': 249,
#   '수작': 250,
#   '해': 251,
#   '싫다': 252,
#   '답답하다': 253,
#   '사실': 254,
#   '추억': 255,
#   '한국영': 256,
#   '가지': 257,
#   '멋있다': 258,
#   '남': 259,
#   '시나리오': 260,
#   '신선하다': 261,
#   '아프다': 262,
#   '관객': 263,
#   '소리': 264,
#   '분위기': 265,
#   '필요없다': 266,
#   '로': 267,
#   '팬': 268,
#   '시대': 269,
#   '장난': 270,
#   '명': 271,
#   '지루함': 272,
#   '어이없다': 273,
#   '나쁘다': 274,
#   '살': 275,
#   '자신': 276,
#   '감정': 277,
#   '졸작': 278,
#   '엔딩': 279,
#   '준': 280,
#   '영화관': 281,
#   '안타깝다': 282,
#   '오늘': 283,
#   '엄마': 284,
#   '봄': 285,
#   '제발': 286,
#   '정신': 287,
#   '접': 288,
#   '인상': 289,
#   '부족하다': 290,
#   '스럽다': 291,
#   '더럽다': 292,
#   '더빙': 293,
#   '포스터': 294,
#   '캐스팅': 295,
#   '최고다': 296,
#   '라면': 297,
#   '평가': 298,
#   '문제': 299,
#   '코믹': 300,
#   '얼마나': 301,
#   '애니메이션': 302,
#   '어색하다': 303,
#   '몰입도': 304,
#   '티비': 305,
#   '기도': 306,
#   '배경': 307,
#   '망하다': 308,
#   '대해': 309,
#   '유쾌하다': 310,
#   '데': 311,
#   '뒤': 312,
#   '맘': 313,
#   '킬링타임': 314,
#   '음': 315,
#   '스릴': 316,
#   '만화': 317,
#   '충격': 318,
#   '얘기': 319,
#   '완벽하다': 320,
#   '전쟁': 321,
#   '존나': 322,
#   '진부하다': 323,
#   '등': 324,
#   '즐겁다': 325,
#   '책': 326,
#   '개연': 327,
#   '예술': 328,
#   '머리': 329,
#   '갈수록': 330,
#   '질': 331,
#   '어디': 332,
#   '얼굴': 333,
#   '매우': 334,
#   '웃기': 335,
#   '머': 336,
#   '후회': 337,
#   '이름': 338,
#   '영화인': 339,
#   '옛날': 340,
#   '구성': 341,
#   '행복하다': 342,
#   '적': 343,
#   '집중': 344,
#   '이후': 345,
#   '장르': 346,
#   '꽤': 347,
#   '집': 348,
#   '주연': 349,
#   '의': 350,
#   '새롭다': 351,
#   '멀다': 352,
#   '날': 353,
#   '다큐': 354,
#   '누구': 355,
#   '시즌': 356,
#   '상황': 357,
#   '건가': 358,
#   '그것': 359,
#   '언제': 360,
#   '짜증': 361,
#   '억지': 362,
#   '씬': 363,
#   '예전': 364,
#   '충분하다': 365,
#   '글': 366,
#   '후반': 367,
#   '비': 368,
#   '역사': 369,
#   '다운': 370,
#   '강추': 371,
#   '걸작': 372,
#   '궁금하다': 373,
#   '불쌍하다': 374,
#   '여기': 375,
#   '누가': 376,
#   '진': 377,
#   '약간': 378,
#   '자기': 379,
#   '두': 380,
#   '소름': 381,
#   '인물': 382,
#   '실화': 383,
#   '해도': 384,
#   '발연기': 385,
#   '그대로': 386,
#   '밉다': 387,
#   '방송': 388,
#   '심하다': 389,
#   '시절': 390,
#   '만점': 391,
#   '잔인하다': 392,
#   '회': 393,
#   '비디오': 394,
#   '대체': 395,
#   '순수하다': 396,
#   '비슷하다': 397,
#   '작': 398,
#   '어렵다': 399,
#   '니': 400,
#   '소설': 401,
#   '한마디': 402,
#   '로맨스': 403,
#   '사회': 404,
#   '아들': 405,
#   '부': 406,
#   '비교': 407,
#   '필요하다': 408,
#   '초딩': 409,
#   '감성': 410,
#   '판': 411,
#   '네이버': 412,
#   '다음': 413,
#   '를': 414,
#   '보': 415,
#   '여배우': 416,
#   '여주': 417,
#   '전체': 418,
#   '간만': 419,
#   '상당하다': 420,
#   '편이': 421,
#   '나이': 422,
#   '사랑스럽다': 423,
#   '당하다': 424,
#   '꿈': 425,
#   '코': 426,
#   '성룡': 427,
#   '굉장하다': 428,
#   '동안': 429,
#   '혼자': 430,
#   '순간': 431,
#   '교훈': 432,
#   '삼류': 433,
#   '은': 434,
#   '존재': 435,
#   '힘': 436,
#   '바로': 437,
#   '주제': 438,
#   '진정하다': 439,
#   '목소리': 440,
#   '년도': 441,
#   '안보': 442,
#   '화려하다': 443,
#   '죽': 444,
#   '당신': 445,
#   '거의': 446,
#   '너': 447,
#   '몇번': 448,
#   '낭비': 449,
#   '가볍다': 450,
#   '년전': 451,
#   '질질': 452,
#   '독특하다': 453,
#   '나라': 454,
#   '엄청나다': 455,
#   '줄거리': 456,
#   '성하다': 457,
#   '자': 458,
#   '의도': 459,
#   '딸': 460,
#   '아버지': 461,
#   '좀비': 462,
#   '판타지': 463,
#   '이번': 464,
#   '갑자기': 465,
#   '어른': 466,
#   '전부': 467,
#   '점주': 468,
#   '상영': 469,
#   '시청률': 470,
#   '흥미롭다': 471,
#   '피': 472,
#   '실제': 473,
#   '넘치다': 474,
#   '신': 475,
#   '평론가': 476,
#   '곳': 477,
#   '맛': 478,
#   '만하': 479,
#   '재': 480,
#   '필요': 481,
#   '땜': 482,
#   '제작': 483,
#   '막': 484,
#   '바': 485,
#   '점점': 486,
#   '한편': 487,
#   '그녀': 488,
#   '화면': 489,
#   '극장판': 490,
#   '초': 491,
#   '중국': 492,
#   '답': 493,
#   '각본': 494,
#   '간다': 495,
#   '볼때': 496,
#   '억지스럽다': 497,
#   '밑': 498,
#   '평': 499,
#   '관람': 500,
#   '이하': 501,
#   '스타일': 502,
#   '란': 503,
#   '세계': 504,
#   '선택': 505,
#   '선': 506,
#   '성우': 507,
#   '요소': 508,
#   '복수': 509,
#   '항상': 510,
#   '일단': 511,
#   '굳다': 512,
#   '둘': 513,
#   '똥': 514,
#   '가치': 515,
#   '뻔': 516,
#   '흥행': 517,
#   '힘드다': 518,
#   '너무하다': 519,
#   '참고': 520,
#   '그때': 521,
#   '더욱': 522,
#   '확실하다': 523,
#   '영': 524,
#   '드': 525,
#   '불편하다': 526,
#   '면': 527,
#   '아빠': 528,
#   '평범하다': 529,
#   '수가': 530,
#   '역대': 531,
#   '거기': 532,
#   '발': 533,
#   '완성': 534,
#   '편집': 535,
#   '단순하다': 536,
#   '상미': 537,
#   '전형': 538,
#   '멜로': 539,
#   '허무하다': 540,
#   '거지': 541,
#   '새끼': 542,
#   '짧다': 543,
#   '세': 544,
#   '화이팅': 545,
#   '역': 546,
#   '어이': 547,
#   '술': 548,
#   '탄탄하다': 549,
#   '진행': 550,
#   '불륜': 551,
#   '구': 552,
#   '엉망': 553,
#   '예상': 554,
#   '병맛': 555,
#   '개그': 556,
#   '잠': 557,
#   '사건': 558,
#   '낫다': 559,
#   '중반': 560,
#   '지겹다': 561,
#   '미화': 562,
#   '소중하다': 563,
#   '그게': 564,
#   '설명': 565,
#   '똑같다': 566,
#   '과거': 567,
#   '또한': 568,
#   '키': 569,
#   '적당하다': 570,
#   '프랑스': 571,
#   '중요하다': 572,
#   '화보': 573,
#   '꿀잼': 574,
#   '훈훈하다': 575,
#   '봣': 576,
#   '도저히': 577,
#   '손': 578,
#   '노력': 579,
#   '흥미진진': 580,
#   '몇': 581,
#   '댓글': 582,
#   '그래픽': 583,
#   '흥미': 584,
#   '거리': 585,
#   '죽음': 586,
#   '원래': 587,
#   '취향': 588,
#   '티': 589,
#   '무조건': 590,
#   '몸': 591,
#   '리': 592,
#   '식상하다': 593,
#   '척': 594,
#   '화가': 595,
#   '뛰어나다': 596,
#   '마르다': 597,
#   '자극': 598,
#   '역겹다': 599,
#   '배': 600,
#   '감상': 601,
#   '울': 602,
#   '한심하다': 603,
#   '학교': 604,
#   '길다': 605,
#   '자꾸': 606,
#   '액션영화': 607,
#   '관': 608,
#   '아저씨': 609,
#   '예고편': 610,
#   '오히려': 611,
#   '바보': 612,
#   '결혼': 613,
#   '심리': 614,
#   '용도': 615,
#   '다가': 616,
#   '속편': 617,
#   '게임': 618,
#   '연기자': 619,
#   '보이': 620,
#   '마무리': 621,
#   '터': 622,
#   '무': 623,
#   '잘만': 624,
#   '강하다': 625,
#   '관계': 626,
#   '천재': 627,
#   '법': 628,
#   '미안하다': 629,
#   '참신하다': 630,
#   '억지로': 631,
#   '표정': 632,
#   '아무': 633,
#   '과': 634,
#   '귀신': 635,
#   '땐': 636,
#   '최근': 637,
#   '전설': 638,
#   '현재': 639,
#   '상상': 640,
#   '유치': 641,
#   '촬영': 642,
#   '산': 643,
#   '대한민국': 644,
#   '타임': 645,
#   '아쉬움': 646,
#   '시': 647,
#   '젠': 648,
#   '짓': 649,
#   '식': 650,
#   '짐': 651,
#   '전편': 652,
#   '길': 653,
#   '스타': 654,
#   '묘사': 655,
#   '대작': 656,
#   '메세지': 657,
#   '진지하다': 658,
#   '열': 659,
#   '철학': 660,
#   '작다': 661,
#   '프로': 662,
#   '총': 663,
#   '프로그램': 664,
#   '동화': 665,
#   '그림': 666,
#   '마': 667,
#   '드럽다': 668,
#   '여전하다': 669,
#   '졸라': 670,
#   '전달': 671,
#   '서로': 672,
#   '역할': 673,
#   '실망하다': 674,
#   '유머': 675,
#   '등장': 676,
#   '조연': 677,
#   '전작': 678,
#   '경찰': 679,
#   '나중': 680,
#   '무비': 681,
#   '다행': 682,
#   '소녀': 683,
#   '여': 684,
#   '먼저': 685,
#   '마치': 686,
#   '멍청하다': 687,
#   '살인': 688,
#   '영원하다': 689,
#   '고': 690,
#   '덥다': 691,
#   '흠': 692,
#   '잘생기다': 693,
#   '흔하다': 694,
#   '오': 695,
#   '특유': 696,
#   '약하다': 697,
#   '행동': 698,
#   '환상': 699,
#   '햇': 700,
#   '저런': 701,
#   '통해': 702,
#   '인정': 703,
#   '런가': 704,
#   '노출': 705,
#   '관심': 706,
#   '주의': 707,
#   '지루': 708,
#   '입': 709,
#   '청춘': 710,
#   '군대': 711,
#   '바람': 712,
#   '노': 713,
#   '착하다': 714,
#   '예산': 715,
#   '리메이크': 716,
#   '낚': 717,
#   '황당하다': 718,
#   '정': 719,
#   '미래': 720,
#   '안나': 721,
#   '깊이': 722,
#   '가능하다': 723,
#   '씨': 724,
#   '제작비': 725,
#   '위대하다': 726,
#   '효과': 727,
#   '망작': 728,
#   '영웅': 729,
#   '그닥': 730,
#   '손발': 731,
#   '생애': 732,
#   '인하다': 733,
#   '시도': 734,
#   '외': 735,
#   '케이블': 736,
#   '평생': 737,
#   '다만': 738,
#   '과정': 739,
#   '반': 740,
#   '반개': 741,
#   '용이': 742,
#   '유명하다': 743,
#   '범인': 744,
#   '온': 745,
#   '희망': 746,
#   '형님': 747,
#   '젊다': 748,
#   '채널': 749,
#   '얼': 750,
#   '미소': 751,
#   '잘못': 752,
#   '가끔': 753,
#   '화': 754,
#   '강': 755,
#   '상상력': 756,
#   '능력': 757,
#   '스케일': 758,
#   '다소': 759,
#   '모': 760,
#   '신기하다': 761,
#   '카메라': 762,
#   '존': 763,
#   '결론': 764,
#   '부터': 765,
#   '광고': 766,
#   '설레다': 767,
#   '독립영화': 768,
#   '대충': 769,
#   '생': 770,
#   '단': 771,
#   '자막': 772,
#   '메시지': 773,
#   '대안': 774,
#   '한계': 775,
#   '체': 776,
#   '고민': 777,
#   '슬픔': 778,
#   '고맙다': 779,
#   '부족': 780,
#   '고생': 781,
#   '빠르다': 782,
#   '여성': 783,
#   '네': 784,
#   '원하다': 785,
#   '변하다': 786,
#   '리얼': 787,
#   '줌': 788,
#   '커플': 789,
#   '산만하다': 790,
#   '동생': 791,
#   '이면': 792,
#   '지난': 793,
#   '어린이': 794,
#   '사이': 795,
#   '방': 796,
#   '리뷰': 797,
#   '거지같다': 798,
#   '박수': 799,
#   '아침': 800,
#   '보시': 801,
#   '차': 802,
#   '유': 803,
#   '시청자': 804,
#   '괴물': 805,
#   '자연': 806,
#   '희다': 807,
#   '살짝': 808,
#   '굳이': 809,
#   '흐름': 810,
#   '로맨틱': 811,
#   '짱짱': 812,
#   '범죄': 813,
#   '밤': 814,
#   '폭력': 815,
#   '연애': 816,
#   '개판': 817,
#   '포장': 818,
#   '게이': 819,
#   '발견': 820,
#   '심심하다': 821,
#   '빨': 822,
#   '진정': 823,
#   '영환': 824,
#   '수도': 825,
#   '악역': 826,
#   '왠만하다': 827,
#   '몸매': 828,
#   '멋': 829,
#   '어찌': 830,
#   '주기': 831,
#   '덕분': 832,
#   '혹시': 833,
#   '포기': 834,
#   '달': 835,
#   '감탄': 836,
#   '진실': 837,
#   '표절': 838,
#   '일상': 839,
#   '시선': 840,
#   '쓰래': 841,
#   '사극': 842,
#   '조폭': 843,
#   '치': 844,
#   '인기': 845,
#   '웬만하다': 846,
#   '랄': 847,
#   '문화': 848,
#   '정서': 849,
#   '성인': 850,
#   '우정': 851,
#   '표': 852,
#   '대의': 853,
#   '과연': 854,
#   '젤': 855,
#   '남녀': 856,
#   '우울하다': 857,
#   '상처': 858,
#   '더하다': 859,
#   '깔끔하다': 860,
#   '뜻': 861,
#   '퀄리티': 862,
#   '암': 863,
#   '쩐다': 864,
#   '불': 865,
#   '끼리': 866,
#   '로서': 867,
#   '유일하다': 868,
#   '홍콩': 869,
#   '성도': 870,
#   '스': 871,
#   '용서': 872,
#   '특별하다': 873,
#   '순': 874,
#   '오락': 875,
#   '심': 876,
#   '이연걸': 877,
#   '죄': 878,
#   '막판': 879,
#   '하루': 880,
#   '코드': 881,
#   '홍보': 882,
#   '크게': 883,
#   '볼거리': 884,
#   '섹스': 885,
#   '말로': 886,
#   '뮤지컬': 887,
#   '국민': 888,
#   '일이': 889,
#   '정치': 890,
#   '보라': 891,
#   '이기': 892,
#   '어제': 893,
#   '간': 894,
#   '느와르': 895,
#   '빛': 896,
#   '싫어하다': 897,
#   '난해하다': 898,
#   '만큼': 899,
#   '등장인물': 900,
#   '원': 901,
#   '해피엔딩': 902,
#   '북한': 903,
#   '보아': 904,
#   '핵': 905,
#   '펑펑': 906,
#   '힐링': 907,
#   '자식': 908,
#   '희생': 909,
#   '첨': 910,
#   '무협': 911,
#   '나머지': 912,
#   '감명': 913,
#   '끌': 914,
#   '형편': 915,
#   '첫': 916,
#   '지도': 917,
#   '눈빛': 918,
#   '반성': 919,
#   '불가': 920,
#   '무겁다': 921,
#   '자유': 922,
#   '남편': 923,
#   '본방': 924,
#   '당연하다': 925,
#   '다큐멘터리': 926,
#   '딱하다': 927,
#   '차이': 928,
#   '춤': 929,
#   '공부': 930,
#   '기술': 931,
#   '개도': 932,
#   '안좋다': 933,
#   '불쾌하다': 934,
#   '뜬금': 935,
#   '열정': 936,
#   '행복': 937,
#   '실감': 938,
#   '올해': 939,
#   '소장': 940,
#   '늘': 941,
#   '기본': 942,
#   '싸움': 943,
#   '노답': 944,
#   '대화': 945,
#   '쫌': 946,
#   '제로': 947,
#   '의문': 948,
#   '입장': 949,
#   '기적': 950,
#   '무시': 951,
#   '비극': 952,
#   '찡하다': 953,
#   '비주': 954,
#   '불구': 955,
#   '뭐임': 956,
#   '따위': 957,
#   '가면': 958,
#   '느리다': 959,
#   '종교': 960,
#   '그다지': 961,
#   '디즈니': 962,
#   '긴장': 963,
#   '색다르다': 964,
#   '싸구려': 965,
#   '지구': 966,
#   '좀더': 967,
#   '결과': 968,
#   '시사회': 969,
#   '실력': 970,
#   '대가': 971,
#   '악당': 972,
#   '호러': 973,
#   '부끄럽다': 974,
#   '아픔': 975,
#   '아줌마': 976,
#   '적절하다': 977,
#   '게다가': 978,
#   '이제야': 979,
#   '동물': 980,
#   '반복': 981,
#   '본인': 982,
#   '촌스럽다': 983,
#   '강렬하다': 984,
#   '아련하다': 985,
#   '인지': 986,
#   '발전': 987,
#   '러닝': 988,
#   '완전하다': 989,
#   '밥': 990,
#   '방금': 991,
#   '아이돌': 992,
#   '단지': 993,
#   '존경': 994,
#   '하하': 995,
#   '빡치다': 996,
#   '짠하다': 997,
#   '분노': 998,
#   '여행': 999,
#   '인': 1000,
#   ...},
#  40014)

# %%
# Sequence 만들기 / Padding하기 - train, test 모두 
training_sequences  = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, 
                                padding=padding_type, truncating=truct_type)


testing_sequences  = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, 
                                padding=padding_type, truncating=truct_type)

# %% [markdown]
# ## Word2Vec weight 만들기

# %%
ko_model

# %%
import numpy as np

vocab_size = len(tokenizer.index_word) + 1
embedding_dim = 200

embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))

# tokenizer에 있는 단어 사전을 순회하면서 word2vec의 200차원 vector를 가져오기
for word, idx in tokenizer.word_index.items():
    embedding_vector = ko_model[word] if word in ko_model else None
    if embedding_vector is not None:
        embedding_matrix[idx] = embedding_vector
        
embedding_matrix.shape
# Out:
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# (40015, 200)

# %%
word_index['최고']

# %%
ko_model['최고']
# Out:
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.20391989,  0.853267  , -1.0373845 , -0.76402867,  0.23367792,
#        -0.10476255,  0.63840646, -0.34341994, -0.65395963, -0.19811577,
#         0.12869409,  0.04804405, -0.29633138,  0.83437115, -0.6217438 ,
#        -0.46856475,  0.6242253 ,  0.23053367,  0.06618986,  0.9534592 ,
#         1.1363881 ,  0.65448356,  0.07115816, -0.04635384,  0.62641287,
#        -0.6753973 ,  0.68135244, -0.16181223, -0.01163022,  0.0247314 ,
#        -0.8546157 , -0.13200873, -0.725247  ,  0.45765552,  0.03358468,
#        -0.6409772 ,  0.67605525,  1.1375098 ,  0.02453117, -0.807451  ,
#         0.00170812, -0.14917341,  0.755414  ,  0.893047  ,  0.36652172,
#         0.10760504, -1.0363314 , -0.14687106,  0.4854047 , -1.525439  ,
#        -0.03832943, -0.43770686, -0.97458017, -1.2530044 , -0.5024239 ,
#         0.13908501, -0.9827486 , -0.42983523, -0.7944189 ,  0.9259701 ,
#        -0.31750435, -0.0639666 ,  0.26727185,  0.34849894, -0.34705332,
#         0.7082175 ,  0.16015601,  1.0106773 , -0.13566843, -0.8825089 ,
#         0.26165384,  1.0536087 , -0.672225  , -1.1582369 , -0.78113145,
#         0.07882488,  0.18336318,  0.1939888 ,  0.9235282 , -0.3342202 ,
#        -1.2136003 , -0.895945  ,  0.28088507, -0.10402039, -0.72383124,
#         0.41007882, -0.84154886,  0.04814413,  0.20372823,  0.29989615,
#        -0.6271573 ,  0.6935575 ,  0.7980351 ,  1.0378351 , -0.11292857,
#         0.18684039,  0.44660008, -0.84701097,  0.963376  ,  0.3238507 ,
#        -0.09019645, -0.95652515, -0.14834665,  0.8852718 , -0.26641536,
#        -0.01317835,  0.12105624, -1.042278  , -0.0806483 ,  0.84633255,
#        -0.22681524, -0.03152812,  0.5583954 ,  0.13800062, -0.28730616,
#         0.9026617 ,  0.01975676,  0.51978445,  0.6538972 , -0.29340315,
#        -0.30554992,  0.16478428, -0.31615463,  1.2710938 , -0.1988536 ,
#        -1.2412758 ,  0.02983495,  0.05643119, -0.40753987, -0.23621982,
#        -0.3855105 , -0.26325995,  0.12984282, -0.25122875, -0.20960635,
#         0.36045936, -0.08154091, -0.12055417,  0.09514962, -0.6951277 ,
#        -0.5638724 ,  0.3605563 , -0.04901775, -0.6449928 , -0.5058511 ,
#        -0.81692505,  0.37752235,  0.04672633, -0.06941879, -0.15216084,
#        -0.7398911 , -0.16161524, -1.5204337 , -0.3370996 ,  0.06805675,
#         0.24068828,  0.0241385 , -0.3026766 , -0.52959967,  0.22209056,
#         0.6985475 , -0.21132225, -0.5624851 ,  0.4839687 ,  0.5820464 ,
#         1.0586027 , -0.65461034,  0.5597646 ,  0.34375298,  0.6003044 ,
#         0.39411226, -0.26936617, -0.66543573,  0.00615932, -0.45602465,
#        -0.73195595,  0.00606945, -0.35158047,  0.11088085,  0.27541614,
#        -0.02916321, -0.37582427, -0.8350914 ,  1.0929366 , -1.0551634 ,
#        -0.14853407,  0.2724459 ,  1.5030024 ,  0.7672227 ,  0.11438014,
#         0.43731147, -0.74036914,  0.15298958, -0.5349135 , -0.03007246,
#        -0.19580878,  0.7381861 , -0.0469554 ,  0.1303526 ,  0.07632774],
#       dtype=float32)

# %%
embedding_matrix[16]
# Out:
# array([-0.85884821,  0.92817163,  0.02203734,  1.36972463, -0.47099909,
#        -1.50105476, -0.49414608,  0.49253559, -0.23244537, -0.04845205,
#         0.09304108, -0.11300896,  0.5571053 , -0.11795222,  0.49380097,
#        -0.55563283,  0.11953602, -0.18062858, -1.25813925, -0.81152546,
#         0.42466506,  0.8579601 ,  0.19897878, -0.81691873,  0.86665642,
#        -1.04654455, -0.49829051,  0.25393131, -0.09490417, -0.93356013,
#        -1.64327502,  0.32434571,  1.26135635,  1.10397637, -0.21867326,
#        -0.55674183,  0.90235335, -1.17161012,  0.77494115, -0.52130711,
#        -0.21292363, -0.30222899, -0.80103284, -0.12620486, -1.19516397,
#        -0.22341141,  0.38163522,  0.00649113,  0.26027831,  0.02779087,
#         0.95976293, -0.24270368, -0.39551368,  0.12866431, -0.59832066,
#         0.12882997, -0.12808815,  0.87104553,  0.00889622, -0.32881373,
#         0.03664391,  0.78057766,  0.28789434,  2.01207733,  0.0571333 ,
#         1.24475467, -0.7004512 , -0.26596418, -0.51164573,  0.31788218,
#         0.68099821, -1.1155411 , -0.09103616, -0.42794025,  0.17228958,
#         0.1538465 , -0.20262402, -0.09419158, -0.04925876,  0.75968885,
#        -1.08090067,  1.34010279,  0.39595917,  1.07487142,  0.67976642,
#        -0.85012221,  0.63369566,  0.2163268 , -0.5303719 , -0.53120828,
#        -0.49126494, -0.85349196,  0.13101861, -0.38891166, -0.02576141,
#        -1.85363209,  0.80570692, -0.37110516, -0.37010357, -0.13792415,
#         0.0872428 , -0.07057373, -0.14079009, -0.0882552 , -1.54146385,
#         0.08164613,  0.57140744,  1.05564296,  0.32159892, -0.27305141,
#        -0.90374011, -0.34642386,  0.76921463, -0.59258711,  1.2521826 ,
#         0.24357602,  0.33998114, -0.69548696,  1.39019847, -0.35703877,
#         0.31514573,  0.11629552, -1.39587677,  0.5845511 ,  0.20291877,
#         1.21480083,  0.18424594, -0.46534598, -0.90870821,  0.44782987,
#         0.82926345, -1.21765888, -0.80595845,  2.11842155,  0.0706705 ,
#         0.35223395,  0.16623954,  0.25785488, -1.0124867 ,  1.34355104,
#         0.57009852, -0.25236714,  1.538589  , -0.20186408,  0.15322793,
#        -0.09332677, -0.37294033,  1.14180744, -1.02544713, -0.36533278,
#        -0.01202002, -0.41665232, -0.59812093, -0.63845223, -0.36218691,
#         1.84820664,  0.69762963, -1.080145  , -1.0401994 ,  0.3541005 ,
#        -0.05727062, -0.70051324, -1.02297199,  0.14561783, -0.17227724,
#        -0.66721731, -0.15351965, -0.12619644, -0.14825901,  0.90405506,
#        -1.17667735,  0.03866967, -0.78964615, -0.11472937,  0.88905376,
#        -0.57539517,  0.17546913,  0.35434532, -0.452573  ,  0.01550079,
#        -0.82413119,  1.16270375, -0.392777  ,  0.08164232,  0.60300821,
#        -0.77959961,  2.22155309,  0.05683346, -0.76498526,  0.74309766,
#         1.2266463 , -0.02246751,  1.29709649, -0.75606471,  1.00340676,
#        -0.45882082, -0.09042309, -0.01749961, -1.04276073,  0.6032626 ])

# %% [markdown]
# ## 모델링

# %%
# 모델링  - L2 추가 
embedding_dim = 200
filter_sizes = (3, 4, 5)
num_filters = 100
dropout = 0.5
hidden_dims = 100

conv_blocks =[]
input_shape = (30)
model_input = tf.keras.layers.Input(shape=input_shape)
z = model_input
for sz in filter_sizes:
    embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length,
                                         weights = [embedding_matrix], trainable = False)(z)
    conv = tf.keras.layers.Conv1D(filters=num_filters,
                         kernel_size=sz,
                         padding="valid",
                         activation="relu",
                         strides=1)(embedding)
    conv = tf.keras.layers.GlobalAveragePooling1D()(conv)
    conv = tf.keras.layers.Flatten()(conv)
    conv_blocks.append(conv)
z = tf.keras.layers.Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]

z = tf.keras.layers.Dense(hidden_dims, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.003), bias_regularizer=tf.keras.regularizers.l2(0.003))(z)
z = tf.keras.layers.Dropout(dropout)(z)
model_output = tf.keras.layers.Dense(1, activation="sigmoid")(z)
model = tf.keras.Model(model_input, model_output)

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 30, 200)      8003000     input_5[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 30, 200)      8003000     input_5[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 30, 200)      8003000     input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 28, 100)      60100       embedding_7[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 27, 100)      80100       embedding_8[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 26, 100)      100100      embedding_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_6 (Glo (None, 100)          0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 100)          0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_8 (Glo (None, 100)          0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 100)          0           global_average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 100)          0           global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 100)          0           global_average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 300)          0           flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          30100       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 100)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            101         dropout_2[0][0]
# ==================================================================================================
# Total params: 24,279,501
# Trainable params: 270,501
# Non-trainable params: 24,009,000
# __________________________________________________________________________________________________

# %%
# 모델 컴파일 
batch_size = 50
num_epochs = 10
min_word_count = 1
context = 10

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# model training 
num_epochs = 30
early_stopping=tf.keras.callbacks.EarlyStopping(patience=2)
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 4556/4556 [==============================] - 138s 30ms/step - loss: 0.4529 - accuracy: 0.8003 - val_loss: 0.4230 - val_accuracy: 0.8107
# Epoch 2/30
#  338/4556 [=>............................] - ETA: 1:52 - loss: 0.4274 - accuracy: 0.8100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-7cb0075768f3> in <module>
#       2 num_epochs = 30
#       3 early_stopping=tf.keras.callbacks.EarlyStopping(patience=2)
# ----> 4 history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), callbacks=[early_stopping])
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~\anaconda\envs\crawl\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
